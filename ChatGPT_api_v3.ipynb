# %%
from openai import OpenAI

"""
    Для работы нужен токен, создать переменную окружения OPENAI_API_KEY
"""
client = OpenAI(api_key="")

def request_extraction_d(prompt):
    stream = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{
                    "role": "system", 
                    "content": """Твоя задача конвертировать текст в последовательный список json структур. Текст из себя представляет инструкцию, последовательность действий, или набор условий если-то. Последовательный список json структур - это шаблонная структура следующего вида { "id": 0-9999, "subject": text "task": text } Ты должен ждать текст и конвертировать его в указанную выше структуру"""},
                {
                    "role": "user",
                    "content": prompt
                }
                ],
        stream=True,
    )
    for chunk in stream:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
            
def request_extraction(prompt):
    stream = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{
                    "role": "system", 
                    "content": """Твоя задача конвертировать текст в последовательный список json структур. Текст из себя представляет инструкцию, последовательность действий, или набор условий если-то. Последовательный список json структур - это шаблонная структура следующего вида { "id": 0-9999, "subject": text "task": text } Ты должен ждать текст и конвертировать его в указанную выше структуру"""},
                {
                    "role": "user",
                    "content": prompt
                }
                ],
        stream=True,
    )
    answer = ''
    for chunk in stream:
        if chunk.choices[0].delta.content is not None:
            answer = chunk.choices[0].delta.content
    return answer

# %%
prompt_1 = """Приготовление кофе.
Подготовка: Убедитесь, что кофемашина выключена и отключена от источника питания. Проверка рабочей поверхности: Очистите рабочую поверхность от пыли, капель и остатков кофе. Заполнение бака для воды: Откройте крышку бака для воды и наполните его свежей питьевой водой до необходимого уровня. Подготовка кофейных зерен: Проверьте наличие достаточного количества кофейных зерен в контейнере. Добавьте новые зерна, если это необходимо. Включение кофемашины: Подключите кофемашину к источнику питания и включите ее. Прогрев кофемашины: Дайте кофемашине прогреться в течение нескольких минут в соответствии с инструкциями производителя. Выбор напитка: Используйте панель управления или экранное меню, чтобы выбрать желаемый напиток (эспрессо, капучино, латте и т.д.). Подготовка чашки: Поставьте чашку под кофемашину в соответствии с выбранным напитком. Приготовление напитка: Нажмите кнопку для приготовления выбранного напитка и дождитесь завершения процесса. Удаление отработанных кофейных гарш: Выньте использованные кофейные гарши и утилизируйте их. Очистка кофемашины: Используйте специальные чистящие средства или таблетки для чистки кофемашины в соответствии с инструкциями производителя. Чистка капучинатора (если есть): Промойте капучинатор теплой водой и средством для чистки, чтобы удалить остатки молока. Очистка капельной подставки: Снимите и очистите капельную подставку от капель кофе и остатков. Очистка фильтра: Если применимо, очистите или замените фильтр кофемашины в соответствии с инструкциями производителя.

Ремонт. Конечно, вот инструкция для ремонта кофемашины при засорившемся фильтре: 1. **Подготовка:** - Убедитесь, что кофемашина выключена и отключена от источника питания. 2. **Доступ к фильтру:** - Откройте дверцу или крышку кофемашины, которая обеспечивает доступ к фильтру. 3. **Выньте фильтр:** - Осторожно извлеките фильтр из его местоположения. Обычно он находится в баке с водой или в системе подачи воды. 4. **Очистка фильтра:** - Тщательно промойте фильтр под проточной водой. Используйте мягкую щетку или специальные средства для очистки, если это необходимо, чтобы удалить все осадки и загрязнения. 5. **Проверка других компонентов:** - Пока фильтр находится вне кофемашины, внимательно осмотрите другие компоненты, связанные с системой подачи воды. Убедитесь, что нет других засорений или проблем. 6. **Возвращение фильтра:** - После того как фильтр будет чистым, верните его на место в соответствии с инструкциями производителя. Убедитесь, что он правильно зафиксирован.
"""

request_extraction_d(prompt_1)
# Out:
# [
#     {
#         "id": 0,
#         "subject": "Приготовление кофе.",
# ...

# %% [markdown]
# Видно что не разделяется тема, сложные действия не делятся на подзадачи. На шаге 20 вклинился текст не относящийся к инструкции

# %%
prompt_2 = """5. Установка и тестирование 
5.1. Требования  
5.1.1. Место установки  
Ознакомьтесь со следующими пунктами: 
Установка кофемашины должна быть выполнена строго на ровной поверхности; несоблюдение данного требования может привести к выходу кофемашины из строя. 
Не устанавливайте кофемашину рядом с источниками тепла. 
Расстояние между источником электричества и машиной должно быть не менее 1 м. 
В месте установки кофемашины должно присутствовать достаточное пространство для обслуживания и ремонта, в т.ч. от задней крышки кофемашины до стены должно быть не менее 5 см для циркуляции воздуха. 
5.1.2. Погодные условия 
Просьба ознакомиться со следующими пунктами, т.к. существует риск повреждения машины: 
Температура окружающей среды должна быть в диапазоне от +10°С до +40°С. 
Максимально допустимая влажность воздуха 80%. 
Использование вне помещения не допускается, т.к. существует риск повреждения машины (дождь, снег, мороз). 
5.1.3. Подключение к электросети 
 
ВНИМАНИЕ! Опасность поражения электричеством! Подключение и напряжение питания должно соответствовать местным требованиям. 
 
Просьба ознакомиться со следующими пунктами: При установке кофемашины питание должно быть выключено. 
Для безопасности, прибор должен быть соединен с автоматическим выключателем замыкания с заземлением 30 мА (УЗО). 
Запрещено использовать кофемашину при повреждении кабеля.  
Не используйте удлинитель! При использовании удлинительной линии (сечение провода должно быть менее 1,5 мм2) соблюдайте требования производителя и правила электробезопасности. 
При прокладке кабеля убедитесь, что люди не спотыкаются о шнур питания. Не позволяйте кабелю проходить через острые углы или висеть в воздухе. Избегайте пережима и залома кабеля.  
Кабель не должен помещаться над высокотемпературными предметами и должен быть защищен от масла и коррозионных чистящих средств. 
Не трогайте кабель. Для соединения через штепсельную вилку, гнездо должно быть легко доступно во время эксплуатации на случай экстренного отключения питания в случае выхода из строя кофемашины.  
Перед подключением убедитесь, что вилка не влажная. 
 
5.1.4. Подключение воды 
Нефильтрованная вода может вызвать повреждение машины. Пожалуйста, соблюдайте следующие пункты:  
Вода должна быть чистой, а содержание хлора не должно превышать 0,5 мг/л. 
Максимальная жесткость воды: 60 мг СаО/л (6°dH). 
Используйте только набор новых трубок! Не разрешается подключать старые или использованные трубки. 
Подключение воды происходит в соответствии с инструкциями и местными правилами. 
Если аппарат подключен к новой трубке, убедитесь в проходимости воды и отсутствие посторонних предметов в трассе водопровода. 
В трассе водопровода должен быть установлен кран выключения.  
При подключении к водопроводу установите редуктор давления (приобретается отдельно) и отрегулируйте его до 0,3 МПа (3 бар). 
 
5.2. Установка 
5.2.1. Кофемашина 
Откройте картонную коробку, извлеките кофемашину и запасные части. Машина и все вспомогательные блоки могут быть установлены только в отапливаемом помещении. 
5.2.2. Установка трубки для молока 
Шаг 1: Вставьте трубку для молока в соединение (одинаковая с обоих сторон); 
 
Шаг 2: Установите второй конец трубки в отверстие поддона для капель.  
 
Установка завершена. В процессе приготовления молочных напитков второй конец трубки должен быть опущен в пакет с молоком. 
 
5.3. Подключение 
5.3.1. Установка трубки подачи воды 
Шаг 1: Соедините конец трубки с гайкой и штуцером подачи воды на машине, закрутите гайку винта по часовой стрелке. 
 
 
Шаг 2: Опустите другой конец трубки в бутыль с водой или подключите его к редуктору давления.  
 
Установка водозаборной трубки завершена. 
 
5.3.2. Отвод использованной воды 
Шаг 1: Достаньте поддон для капель. 
 
Шаг 2: Установите трубку отвода использованной воды (Ø12,5 мм, приобретается отдельно) на патрубок в нижней задней части поддона, закрепите фиксирующим хомутом и пропустите трубку в отверстие через заднюю стенку кофемашины. 
 
Шаг 3: Другой конец трубки поместите в емкость для стока воды. 
 
 	 
5.4. Питание 
5.4.1. Подключение питания 
Напряжение питания должно соответствовать данным на паспорте оборудования.  
Шаг 1: Подключите клемму кабеля к розетке кофемашины. 

При соединении через штепсельную вилку, гнездо должно быть легко доступно во время работы и иметь возможность отключения в случае неисправности.
"""

# %%
request_extraction_d(prompt_2)
# Out:
# [
#     {
#         "id": 1,
#         "subject": "Установка и тестирование",
#         "task": "Требования"
#     },
#     {
#         "id": 2,
#         "subject": "Установка и тестирование",
#         "task": "Место установки",
#         "subtasks": [
#             {
#                 "id": 3,
#                 "subtask": "Ознакомьтесь со следующими пунктами:"
#             },
#             {
#                 "id": 4,
#                 "subtask": "Установка кофемашины должна быть выполнена строго на ровной поверхности; несоблюдение данного требования может привести к выходу кофемашины из строя."
#             },
#             {
#                 "id": 5,
#                 "subtask": "Не устанавливайте кофемашину рядом с источниками тепла."
#             },
#             {
#                 "id": 6,
#                 "subtask": "Расстояние между источником электричества и машиной должно быть не менее 1 м."
#             },
#             {
#                 "id": 7,
# ...

# %% [markdown]
# Это пример для обучения. Проанализируй его и сделай правки в свой вывод.
# Вводим: "5. Установка и тестирование
# 5.1. Требования
# 5.1.1. Место установки
# Ознакомьтесь со следующими пунктами:
# Установка кофемашины должна быть выполнена строго на ровной поверхности; несоблюдение данного требования может привести к выходу кофемашины из строя.
# Не устанавливайте кофемашину рядом с источниками тепла.
# Расстояние между источником электричества и машиной должно быть не менее 1 м.
# В месте установки кофемашины должно присутствовать достаточное пространство для обслуживания и ремонта, в т.ч. от задней крышки кофемашины до стены должно быть не менее 5 см для циркуляции воздуха. "
#
# получаем:
# {
# "object": "кофемашина",
#   "steps": [
#     {
#       "step": 1,
#       "task": "Проверка требований для установки. Определите наилучшее место"
#     },
#  {
#       "step": 2,
#       "task": "Убедитесь что поверхность ровная"
#     },
#  {
#       "step": 3,
#       "task": "Рядом не должно быть источников тепла"
#     },
#  {
#       "step": 4,
#       "task": "Убедитесь что расстояние между источником электричества и машиной должно быть не менее 1 м."
#     },
# {
#       "step": 5,
#       "task": "На случай неисправности должно быть достаточно места для ремонта, минимум 5 см от задней крышки для циркуляции воздуха"
#     },
# }

# %%
messages=[
    {
        "role": "system",
        "content": """Твоя роль проанализировать в последующих сообщениях текст. Тебе нужно понять о каком объекте в тексте идёт речь. Понять последовательность действий с этим объектом. 
Объедини вывод в сообщение формата json как на примере ниже:
{
"object" : то что должно иследоваться,
[
{"step" : 1, "task" :  описываемое действие 1},
{"step" : 2, "task" :  описываемое действие 2},
...
]
}
"""
    },
]

# %%
import midas

pdfpInstance = midas.PDFP("""./Sources/Dr.Coffee-f11 .pdf""")
result = ""
for manual_chapter in pdfpInstance:
    request_extraction_d(manual_chapter)
    
print(result)
# Out:
# [
#     {
#         "id": 0,
#         "subject": "Безопасность",
#         "task": "Безопасность является одной из важнейших для нас задач. Во избежание несчастных случаев, строго следуйте приводимым инструкциям."
#     },
#     {
#         "id": 1,
#         "subject": "Безопасность",
#         "task": "Назначение: Данная кофемашина и все комплектующие предназначены для установки и эксплуатации для приготовления кофе и кофейных напитков в сухих закрытых помещениях с постоянным подключением к водоснабжению или использованию чистой питьевой воды без принудительной подачи. Использование только пользователями, прошедшими обучение. Техническое обслуживание должно производиться обученными специалистами."
#     },
#     {
#         "id": 2,
#         "subject": "Безопасность",
#         "task": "Назначение: Данная кофемашина и все комплектующие не предназначены для использования в условиях высокой влажности и на улице."
#     },
#     {
#         "id": 3,
# ...
